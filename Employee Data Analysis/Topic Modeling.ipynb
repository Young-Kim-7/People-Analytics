# %% [markdown]
# ### **Install Natural Language ToolKit (NLTK) module (and some other modules)**

# %%
#the module 'sys' allows istalling module from inside Jupyter
import sys

# !{sys.executable} -m pip install numpy
import numpy as np

# !{sys.executable} -m pip install pandas
import pandas as pd

#Natrual Language ToolKit (NLTK)
# !{sys.executable} -m pip install nltk
import nltk

# !{sys.executable} -m pip install sklearn
from sklearn import metrics
#from sklearn.model_selection import GridSearchCV
from sklearn.feature_extraction.text import  CountVectorizer #bag-of-words vectorizer
from sklearn.decomposition import LatentDirichletAllocation #package for LDA

# Plotting tools

from pprint import pprint
# !{sys.executable} -m pip install pyLDAvis #visualizing LDA
import pyLDAvis
import pyLDAvis.lda_model

import matplotlib.pyplot as plt
# %matplotlib inline

#define text normalization function
# %run ./Text_Normalization_Function.ipynb #defining text normalization function

#ignore warnings about future changes in functions as they take too much space
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)
# Collecting sklearn
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Requirement already satisfied: pyLDAvis in /usr/local/lib/python3.10/dist-packages (3.4.1)
# Requirement already satisfied: numpy>=1.24.2 in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (1.11.4)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (2.0.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (1.4.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (3.1.3)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (2.10.0)
# Requirement already satisfied: funcy in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (2.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (1.2.2)
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (4.3.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (67.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->pyLDAvis) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->pyLDAvis) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->pyLDAvis) (3.4.0)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim->pyLDAvis) (6.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->pyLDAvis) (2.1.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->pyLDAvis) (1.16.0)
# Requirement already satisfied: html.parser in /usr/local/lib/python3.10/dist-packages (0.2)
# Requirement already satisfied: ply in /usr/local/lib/python3.10/dist-packages (from html.parser) (3.11)
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Requirement already satisfied: pattern3 in /usr/local/lib/python3.10/dist-packages (3.0.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from pattern3) (4.12.3)
# Requirement already satisfied: cherrypy in /usr/local/lib/python3.10/dist-packages (from pattern3) (18.9.0)
# Requirement already satisfied: docx in /usr/local/lib/python3.10/dist-packages (from pattern3) (0.2.4)
# Requirement already satisfied: feedparser in /usr/local/lib/python3.10/dist-packages (from pattern3) (6.0.11)
# Requirement already satisfied: pdfminer3k in /usr/local/lib/python3.10/dist-packages (from pattern3) (1.3.4)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.10/dist-packages (from pattern3) (3.19.2)
# Requirement already satisfied: pdfminer.six in /usr/local/lib/python3.10/dist-packages (from pattern3) (20231228)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->pattern3) (2.5)
# Requirement already satisfied: cheroot>=8.2.1 in /usr/local/lib/python3.10/dist-packages (from cherrypy->pattern3) (10.0.0)
# Requirement already satisfied: portend>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from cherrypy->pattern3) (3.2.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from cherrypy->pattern3) (10.1.0)
# Requirement already satisfied: zc.lockfile in /usr/local/lib/python3.10/dist-packages (from cherrypy->pattern3) (3.0.post1)
# Requirement already satisfied: jaraco.collections in /usr/local/lib/python3.10/dist-packages (from cherrypy->pattern3) (5.0.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from docx->pattern3) (4.9.4)
# Requirement already satisfied: Pillow>=2.0 in /usr/local/lib/python3.10/dist-packages (from docx->pattern3) (9.4.0)
# Requirement already satisfied: sgmllib3k in /usr/local/lib/python3.10/dist-packages (from feedparser->pattern3) (1.0.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six->pattern3) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six->pattern3) (42.0.5)
# Requirement already satisfied: ply in /usr/local/lib/python3.10/dist-packages (from pdfminer3k->pattern3) (3.11)
# Requirement already satisfied: jaraco.functools in /usr/local/lib/python3.10/dist-packages (from cheroot>=8.2.1->cherrypy->pattern3) (4.0.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six->pattern3) (1.16.0)
# Requirement already satisfied: tempora>=1.8 in /usr/local/lib/python3.10/dist-packages (from portend>=2.1.1->cherrypy->pattern3) (5.5.1)
# Requirement already satisfied: jaraco.text in /usr/local/lib/python3.10/dist-packages (from jaraco.collections->cherrypy->pattern3) (3.12.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from zc.lockfile->cherrypy->pattern3) (67.7.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->pattern3) (2.22)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from tempora>=1.8->portend>=2.1.1->cherrypy->pattern3) (2023.4)
# Requirement already satisfied: jaraco.context>=4.1 in /usr/local/lib/python3.10/dist-packages (from jaraco.text->jaraco.collections->cherrypy->pattern3) (5.3.0)
# Requirement already satisfied: autocommand in /usr/local/lib/python3.10/dist-packages (from jaraco.text->jaraco.collections->cherrypy->pattern3) (2.2.2)
# Requirement already satisfied: inflect in /usr/local/lib/python3.10/dist-packages (from jaraco.text->jaraco.collections->cherrypy->pattern3) (7.0.0)
# Requirement already satisfied: backports.tarfile in /usr/local/lib/python3.10/dist-packages (from jaraco.context>=4.1->jaraco.text->jaraco.collections->cherrypy->pattern3) (1.1.0)
# Requirement already satisfied: pydantic>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from inflect->jaraco.text->jaraco.collections->cherrypy->pattern3) (2.7.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from inflect->jaraco.text->jaraco.collections->cherrypy->pattern3) (4.11.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9.1->inflect->jaraco.text->jaraco.collections->cherrypy->pattern3) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9.1->inflect->jaraco.text->jaraco.collections->cherrypy->pattern3) (2.18.1)
# Requirement already satisfied: pyLDAvis in /usr/local/lib/python3.10/dist-packages (3.4.1)
# Requirement already satisfied: numpy>=1.24.2 in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (1.11.4)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (2.0.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (1.4.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (3.1.3)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (2.10.0)
# Requirement already satisfied: funcy in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (2.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (1.2.2)
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (4.3.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (67.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->pyLDAvis) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->pyLDAvis) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->pyLDAvis) (3.4.0)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim->pyLDAvis) (6.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->pyLDAvis) (2.1.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->pyLDAvis) (1.16.0)
# Original:   <p>The circus dog in a plissé skirt jumped over Python who wasn't that large, just 3 feet long.</p>
# Processed:  ['<', 'p', '>', 'The', 'circus', 'dog', 'in', 'a', 'plissé', 'skirt', 'jumped', 'over', 'Python', 'who', 'was', "n't", 'that', 'large', ',', 'just', '3', 'feet', 'long.', '<', '/p', '>']
# Original:   <p>The circus dog in a plissé skirt jumped over Python who wasn't that large, just 3 feet long.</p>
# Processed:  <p>The circus dog in a plissé skirt jumped over Python who was not that large, just 3 feet long.</p>
# Original:   <p>The circus dog in a plissé skirt jumped over Python who wasn't that large, just 3 feet long.</p>
# Processed:  [('<', 'a'), ('p', 'n'), ('>', 'v'), ('the', None), ('circus', 'n'), ('dog', 'n'), ('in', None), ('a', None), ('plissé', 'n'), ('skirt', 'n'), ('jumped', 'v'), ('over', None), ('python', 'n'), ('who', None), ('was', 'v'), ("n't", 'r'), ('that', None), ('large', 'a'), (',', None), ('just', 'r'), ('3', None), ('feet', 'n'), ('long.', 'a'), ('<', 'n'), ('/p', 'n'), ('>', 'n')]
# Original:   <p>The circus dog in a plissé skirt jumped over Python who wasn't that large, just 3 feet long.</p>
# Processed:  < p > the circus dog in a plissé skirt jump over python who be n't that large , just 3 foot long. < /p >
# Original:   <p>The circus dog in a plissé skirt jumped over Python who wasn't that large, just 3 feet long.</p>
# Processed:    p   The circus dog in a plissé skirt jumped over Python who was n t that large   just 3 feet long     p
# Original:   <p>The circus dog in a plissé skirt jumped over Python who wasn't that large, just 3 feet long.</p>
# Processed:  < p > The circus dog plissé skirt jumped Python n't large , 3 feet long. < /p >
# Original:   <p>The circus dog in a plissé skirt jumped over Python who wasn't that large, just 3 feet long.</p>
# Processed:  p The circus dog in a plissé skirt jumped over Python who was n't that large just feet long. /p
# Original:   <p>The circus dog in a plissé skirt jumped over Python who wasn't that large, just 3 feet long.</p>
# Processed:  The circus dog in a plissé skirt jumped over Python who wasn't that large, just 3 feet long.
# Original:   <p>The circus dog in a plissé skirt jumped over Python who wasn't that large, just 3 feet long.</p>
# Processed:  <p>The circus dog in a plisse skirt jumped over Python who wasn't that large, just 3 feet long.</p>
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ### **Read the CSV file**

# %%
# Now use pandas to read the csv file
intern_survey = pd.read_csv("/content/Intern Surveys to Inter 2018-2021.csv")

# %%
# Read open-ended questions
challenges = intern_survey["Challenges"]
virtual_work_impacting_on_performance = intern_survey["Virtual work impacting on performance"]

# %% [markdown]
# ### **Open-ened Question 1: Challenges**

# %%
# Change 'business_area_goals_and_work' into a list of strings
STR_virtual_work_impacting_on_performance = []
for item in virtual_work_impacting_on_performance:
    if isinstance(item, float):
        item = str(item)
    STR_virtual_work_impacting_on_performance.append(item)

# %%
# Eliminate missing values
STR_virtual_work_impacting_on_performance = [item for item in STR_virtual_work_impacting_on_performance if item != 'nan']
STR_virtual_work_impacting_on_performance
# Out:
# ["Absolutely. I know it is an unfortunate situation and a lot of the aspects that make the internship as strong as it is can't be replicated remotely. \n\nI think working in the research department though I'd hoped to get to work on a challenging project that challenged my economic skills. But, I also understand this is hard for managers to provide in the WFH environment because it is harder to get over that learning curve remotely.  ",
#  'As I stated earlier, there are a lot of distractions when working from home. However, I have been able to overcome these distractions with time and focus on assignments. ',
#  'As mentioned above, it can feel a bit isolating. I also feel like my managers are busy people so I often am waiting for higher-ups to get back to me. ',
#  "As stated above, technology-wise it does present some challenges and has taken up a bit more time than expected. In addition, being at home with my family can be difficult as my work day isn't always entirely uninterrupted, so some days it can be more challenging to be productive than others. Overall though, I feel like these are typical struggles when working from home, and I experienced this with school as well. ",
#  "Even though I'm extremely grateful that the internship is still happening, the virtual experience feels less immersive. I don't get to see the buildings, the offices, or even people's body languages. Similar to school, any experience that's online versus being in person makes the opportunity feel less inclusive.",
#  "Everyone is in a conference call all day and being virtual is kind of isolating, so I'm hesitant to reach out and ask questions. I'm also always anxious over the fact that I have no idea what people are thinking about me or my performance because I can't tell over email, chat, or Skype calls. Without that existing rapport, they don't know me and I don't know them, so I have no sense of gauging anything without being there and reading body language. ",
#  "For me personally, I find it a lot harder to focus when I am at home. In college, I COULD NOT study in my dorm room; I always had to go to the library or Starbucks if I wanted to get things done. The same thing applies to this situation, except I don't really have anywhere to go. I have tried taking frequent breaks, turning off my phone, things like that, but I still don't think I am as focused as I would be in the bank. ",
#  "I am not able to focus as long while working virtually. I think the connections I'm making are not as strong as they could be due to virtual meetings rather than daily in-person interactions. I understand that these are barriers that inevitably come with working virtually and I appreciate all of the group meetings the coordinators have organized with senior leaders and our intern cohort.",
#  'I am still able to get ',
#  'I believe I would be more productive at the bank. Being at home can have its distractions. I enjoy an environment where I can work with people in person. Also, our projects have required collaboration with a whiteboard. A virtual whiteboard is not very easy to work with.',
#  'I believe it is more challenging to connect with fellow employees and swap ideas on a consistent basis virtually, as opposed to working in-person. ',
#  'I believe working from home on a daily basis is less motivating and productive than working in person would be. It can also be distracting to work while surrounded by family members who are not in work mode.',
#  "I do miss some of the socializing that I believe there otherwise would be, and I tend to find it easier to network and connect with people when I can meet them face to face, but other than that, I'm really satisfied. I also do think that these issues are unavoidable. ",
#  "I feel I'm more productive virtually, as I'm just less distracted in my room, am more relaxed, and can work for longer periods of time. I still do miss the peer interaction of an in-person setting, though.",
#  'I have had recent setbacks at home, and it can be challenging to focus',
#  "I have trouble staying focused for long periods of time, so working for eight hours straight can be pretty challenging for me. This past year, I went back to school in-person and I noticed that my ability to focus significantly improved, most likely because I had different environments, people around me, things to keep my mind occupied. Now, just sitting in my office for eight hours a day, there is no change of scenery, I'm not really seeing any people, and it's making me a bit burnt out",
#  'I think I could make better connections if I were in person. ',
#  'I think it has helped with time management. For me it, it would take about an hour and a half of traveling to get to and from the bank each day. So while not seeing people is not as great, it has helped me do more with my free time. More in free time generally equals less stress and probably more focus during the workday. In addition, I can also structure my breaks a bit more personally. For example, during lunch break, I eat throughout the day so I usually finish pretty quickly (five-ten minutes). So I usually take a quiet ten-fifteen minute nap that reinvigorates me for the rest of the day. This would not be feasible in the workplace. I think the ideal work conditions going forward are a blend of virtual and in person attributes.',
#  'I think working in an office allows me to understand by projects better because I am able to show people what I am struggling with and working on in real time, and they are able to know exactly what my problem is. In the virtual environment, getting questions answered is delayed because you need to set up meetings or send an email. This delay makes me feel like my productivity is not what it could be if I was working in an office.',
#  'I think working virtually ha',
#  'I think working virtually has',
#  'I work better in office. Communication with others can happen more organically making networking easier. Ease of communication also makes getting direction easier. ',
#  "I'm not sure for better or for worse, but it's very different. Pros- I can hang out with our foster dogs during the day and I take breaks and run around outside with them, so I feel very refreshed and not like I'm in a traditional office. Cons- I feel a little more distracted and it's harder to talk with people quickly about projects (over Skype it's not the same, and we don't always have a meeting set). I do miss popping my head into people's cubicles/offices to ask questions.",
#  "It has taught me to manage my time well and also realize that breaks are necessary for efficient work. I think society has taught us that we need to be working 100% of the time, but with virtual work, that is pretty impossible. It's important that we give ourselves short breaks to recharge.",
#  'It is hard to stare at a computer all day with no in-person human interaction. Also, it is easy to lose track of time. I will work for hours straight without realizing it, when I should be taking breaks to stand.',
#  'It is more difficult to understand the workplace culture as well as to get to know other people at the Bank.',
#  'It makes it harder to network, although I am still meeting lots of people, it is harder to make those meaningful connections. I also think that my material would simply be easier to comprehend if I were in the office with my mentor and manager.',
#  "It's a double-edged sword. On one hand, being able to interact with people and just swing by a cubicle makes collaboration a fair bit easier, which is huge for in person work. On the other, I find it easier to get in the zone when remote. I'm not sure if I'm more efficient, but it feels like I might be. Honestly, I'd say I probably perform equally well under both conditions.",
#  "It's been more challenging to network than it would be otherwise.\n\nThough it's certainly cheaper, I find myself disengaging from Teams meetings to work independently quite frequently which wouldn't be a temptation in person. ",
#  "It's definitely hard not to feel a little isolated through all of this, although I think the internship program does a good job of helping interns feel comfortable reaching out to others at the bank for networking and just getting to know them!",
#  "It's harder to ask questions or get help. Now you have to reach out and set up a call or wait for an email response where before it'd be a quick question in person.",
#  "It's harder to stay focus and harder to connect with people. Everyone is trying their hardest to make it the same experience, but it is the nature of a virtual environment. ",
#  "It's more difficult to make connections/network in a virtual environment",
#  "I've found that not being around the people I'm working with makes me more distracted which can be bad for my productivity.",
#  'Lack of time to make true connections with other interns. I have connected 1 on 1 with other interns, but still not the same as if we were sharing the same office completing tasks together. I feel like I would be busier or at least seem busier if I was in the bank. ',
#  "Often, it's tough to maintain focus when not in an office. I try and break up each day the best I can, but of course it's still difficult! I think this article in the Wall Street Journal characterizes a lot of the challenges of virtual internships, and it has some great recommendations: https://www.wsj.com/articles/interns-seek-solutions-to-isolation-during-the-summer-of-coronavirus-11594598400. For example, to add some variety to each day, I think it would be really great if we organized some (mandatory?) social events for all interns. Maybe small group coffee chats or a one-on-one random pairings with another intern every morning, could be fun. Events like those could help change focus for a little bit and add some more variety to the day, while also providing a great networking opportunity with other interns we haven't necessarily interacted with much.",
#  'Slightly because I have to balance my home and work life.',
#  'The Bank has done an incredible job transitioning the internship to virtual, and I am so grateful that you did. I do think it is a little more difficult to make connections with other people/interns virtually, and this makes it harder to have casual conversations about our work, clarifications on something, etc. I would say working virtually has impacted my performance but not drastically so.',
#  'This virtual format has had a slight impact on my performance. While I am focused and prioritizing my work to the highest standard, I feel that there is a level of focus that I would have if I were to working at the bank. It is simply due to the nature of this virtual environment, and so far I have been able to adapt and be successful. ',
#  "Working remotely has, in my opinion, increased the time it took to get started with work.  Not being able to go over to someone's desk to ask a question creates a lag in communication, which is oftentimes inevitable in an online setting.  Once the getting-started period ended, productivity increased. ",
#  "Yes, I think it has. I have learned the importance of communication since I can't talk to the person face-to-face, and it's helped me see how time management is key. While I do think I'm more productive working in person, I've figured out ways to keep me motivated and on task.",
#  'Yes, my internet is unreliable or too slow to maintain a video call. This impacted my ability to contribute to conversations or present. Thankfully, most of the time it is good enough to maintain an audio connection, but it has impacted my performance.']

# %% [markdown]
# ## **Define two functions what will display the results of fitting a topic model.**

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic %d:" % (topic_idx))
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))

def get_topic_words(vectorizer, lda_model, n_words):
    keywords = np.array(vectorizer.get_feature_names_out())
    topic_words = []
    for topic_weights in lda_model.components_:
        top_word_locs = (-topic_weights).argsort()[:n_words]
        topic_words.append(keywords.take(top_word_locs).tolist())
    return topic_words

# %% [markdown]
# ## **Text Normalization & Vectorization**

# %% [markdown]
# By normalizing text, we can elmininate stopwords, extend contractions, do stemming or lemmatization.

# %%
# Normalize text
NORM_Q2 = normalize_corpus(STR_virtual_work_impacting_on_performance)

# %% [markdown]
# Since for topic modeling we need text data in the Bag-of-Words representation, let's vectorize our normalized_toy_corpus and call it bow_toy_corpus:

# %%
#define the bag-of-words vectorizer:
bow_vectorizer = CountVectorizer()

#vectorize the normalized data:
bow_Q2 = bow_vectorizer.fit_transform(NORM_Q2)

# %% [markdown]
# Have a look at the Bag-of-Words representation of our corpus

# %%
df = pd.DataFrame(data = bow_Q2.todense(), columns = bow_vectorizer.get_feature_names_out())

# %%
# Assuming 'df' is your DataFrame
column_sums = df.sum()
sorted_sums = column_sums.sort_values(ascending=False)
sorted_sums
# Out:
# work       37
# think      19
# people     17
# time       15
# person     15
#            ..
# human       1
# huge        1
# http        1
# however     1
# zone        1
# Length: 423, dtype: int64

# %% [markdown]
# ## **Topic Model (via Latent Dirichlet Allocation) on Q1 Data**
#
# We will be using the LatentDirichletAllocation function which we already imported earlier (see installation of toolkit). The function has the following parameters to be set:
#
# 1. Number of topics to model: n_components
# 2. Parameter vector for the Dirichlet distribution for topics in a document: doc_topic_prior
# 3. Parameter vector for the Dirichlet distribution for words in a topic: topic_word_prior
#
# Now, let's set the parameters and estimate the topic model:

# %%
lda_Q2_corpus = LatentDirichletAllocation(n_components=4, max_iter=500,
                                           doc_topic_prior = 0.25,
                                           topic_word_prior = 0.25).fit(bow_Q2)

# %% [markdown]
# Display results by showing 10 most frequent (top) words for each topic

# %%
no_top_words = 10
display_topics(lda_Q2_corpus, bow_vectorizer.get_feature_names_out(), no_top_words)
# Out:
# Topic 0:
# work time feel able office virtual network person easy still
# Topic 1:
# work hard think virtually bank difficult home internship thing know
# Topic 2:
# person think day people work focus time bit help easy
# Topic 3:
# people feel virtual focus hard work meeting experience home person

# %% [markdown]
# Let's look at the relative frequency of the word of topics in a descending order.

# %%
word_weights = lda_Q2_corpus.components_ / lda_Q2_corpus.components_.sum(axis=1)[:, np.newaxis]
word_weights_df = pd.DataFrame(word_weights.T,
                               index = bow_vectorizer.get_feature_names_out(),
                               columns = ["Topic_" + str(i) for i in range(4)])
word_weights_df.sort_values(by='Topic_0',ascending=False).head(10)
# Out:
#           Topic_0   Topic_1   Topic_2   Topic_3
# work     0.051770  0.027750  0.018452  0.015316
# time     0.020531  0.007575  0.013420  0.004468
# feel     0.017676  0.010951  0.003165  0.015441
# able     0.014847  0.000843  0.003181  0.008167
# office   0.014844  0.000843  0.005741  0.008159
# virtual  0.014839  0.004192  0.008295  0.015439
# network  0.012027  0.000843  0.003180  0.000907
# person   0.012024  0.004148  0.018553  0.011777
# easy     0.012014  0.000843  0.010849  0.000907
# still    0.012006  0.004214  0.003194  0.004537

# %% [markdown]
# ## **Topic Modeling Visualization**
#
# We can visualize the topics: topic size, frequency of words in a topic and so on. In this visualization, we can rank words in a topic by relevancy: Relevancy parameter is λ (0 ≤ λ ≤ 1).
#
# *   small λ highlights potentially rare, but exclusive terms for the selected topic;
# *   large values of λ (near 1) highlight frequent, but not necessarily exclusive, terms for the selected topic;
#
# Relevancy = λ log[p(term | topic)] + (1 - λ) log[p(term | topic)/p(term)],
#
# We installed all the pyLDAvis module required for this visualization in Toolkit. Not let's use it:

# %%
#prepare to display result in the Jupyter notebook
pyLDAvis.enable_notebook()

#run the visualization [mds is a function to use for visualizing the "distance" between topics]
pyLDAvis.lda_model.prepare(lda_Q2_corpus, bow_Q2, bow_vectorizer, mds='tsne')
# Out:
# PreparedData(topic_coordinates=               x          y  topics  cluster       Freq
# topic
# 2      16.812860 -87.325089       1        1  32.084340
# 0     -54.854027 -89.248886       2        1  27.351525
# 1     -57.463196 -17.704569       3        1  21.405598
# 3      14.010974 -15.732894       4        1  19.158537, topic_info=           Term       Freq      Total Category  logprob  loglift
# 154        hard   9.000000   9.000000  Default  30.0000  30.0000
# 414        work  25.000000  25.000000  Default  29.0000  29.0000
# 226     meeting   3.000000   3.000000  Default  28.0000  28.0000
# 119  experience   3.000000   3.000000  Default  27.0000  27.0000
# 1          able   6.000000   6.000000  Default  26.0000  26.0000
# ..          ...        ...        ...      ...      ...      ...
# 379       think   2.014025  13.620781   Topic4  -4.4443  -0.2590
# 404   virtually   1.405436   5.922538   Topic4  -4.8041   0.2140
# 1          able   1.400413   6.109671   Topic4  -4.8076   0.1793
# 248      office   1.399090   6.842940   Topic4  -4.8086   0.0650
# 76          day   1.399641   9.031331   Topic4  -4.8082  -0.2121
#
# [248 rows x 6 columns], token_table=      Topic      Freq        Term
# term
# 1         1  0.163675        able
# 1         2  0.654700        able
# 1         4  0.163675        able
# 2         3  0.758341  absolutely
# 4         1  0.934982         add
# ...     ...       ...         ...
# 413       4  0.383336     without
# 414       1  0.192944        work
# 414       2  0.501654        work
# 414       3  0.192944        work
# 414       4  0.115766        work
#
# [301 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[3, 1, 2, 4])

# %% [markdown]
# ## **Find a dominant topin in a answer**
#
# Let's assign a dominant topic to each answer in our corpus. Weights in a word vector for a topic provide a measure of association for the word with the topic. If you sum weights for a particular topic across all words in a answer, you'll get the weight of that topic in the answer.

# %%
lda_Q1_corpus_weights = lda_Q1_corpus.transform(bow_Q1)

# %% [markdown]
# Let's convert lda_Q1_corpus_weights into a nice-looking dataframe and have a look at the computed topic weights in documents:

# %%
#array of answer "names" and topic "names" ("names" are just indecies)
ans_names = ["Ans_" + str(i) for i in range(len(NORM_Q1))]
topic_names = ["Topic_" + str(i) for i in range(4)]

#convert to dataframe
df_answer_topic = pd.DataFrame(np.round(lda_Q1_corpus_weights, 4), columns=topic_names, index=ans_names)
df_answer_topic.head(5)
# Out:
#        Topic_0  Topic_1  Topic_2  Topic_3
# Ans_0   0.9430   0.0200   0.0189   0.0181
# Ans_1   0.0288   0.9141   0.0291   0.0281
# Ans_2   0.0188   0.9446   0.0186   0.0180
# Ans_3   0.0096   0.9711   0.0097   0.0096
# Ans_4   0.0281   0.9151   0.0289   0.0279

# %% [markdown]
# The topic with the highest weight in each document is a dominant topic. The weights across the 4 topics sum up to 1. Let's add a column that shows dominant topic for each document:

# %%
#vector of indecies for columns with the highest value by each row in df_answer_topic
dominant_topic = np.argmax(df_answer_topic.values, axis=1)

#add dominant_topic as a column to df_document_topic
df_answer_topic['dominant_topic'] = dominant_topic
df_answer_topic.head(5)
# Out:
#        Topic_0  Topic_1  Topic_2  Topic_3  dominant_topic
# Ans_0   0.9430   0.0200   0.0189   0.0181               0
# Ans_1   0.0288   0.9141   0.0291   0.0281               1
# Ans_2   0.0188   0.9446   0.0186   0.0180               1
# Ans_3   0.0096   0.9711   0.0097   0.0096               1
# Ans_4   0.0281   0.9151   0.0289   0.0279               1

# %% [markdown]
# ## **Topic Meol Evaluation: Coherence Scores**
#
# We will use a function CoherenceModel() from the gensim module

# %%
# !{sys.executable} -m pip install gensim
import gensim

from gensim.models.coherencemodel import CoherenceModel
from gensim.corpora.dictionary import Dictionary
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.25.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (6.4.0)

# %% [markdown]
# The function CoherenceModel() needs as inputs:
#
# 1. Dictionary of the corpus
# 2. Corpus with each document represented as Bag-of-Words
# 3. An array of top words for each topic: we'll have top 20 words for each topic
#
# We will now create those objects:

# %%
#tokenizing the corpus
Q1_corpus_tokenized = [tokenize_text(NORM_Q1[ans_id]) for ans_id in range(len(NORM_Q1))]

#Dictionary of the corpus:
Q1_dictionary = Dictionary(Q1_corpus_tokenized)

#Bag-of-words representation for each document of the corpus:
Q1_corpus_bow = [Q1_dictionary.doc2bow(ans) for ans in Q1_corpus_tokenized]

#top 20 words for each topic (using the function defined in toolkit)
topic_topwords = get_topic_words(vectorizer = bow_vectorizer, lda_model = lda_Q1_corpus, n_words=20)

# %% [markdown]
# Now let's compute the coherence score for the model overall. We use one of the coherence metrics "u-mass" which measures semantic similarity of words in a topic, but there are other metrics as well.

# %%
cm = CoherenceModel(topics=topic_topwords,
                    corpus = Q1_corpus_bow ,
                    dictionary = Q1_dictionary, coherence='u_mass')
print("Coherence score for the model: ", np.round(cm.get_coherence(), 4))  # get coherence value
# Out:
# Coherence score for the model:  -6.2575

# %% [markdown]
# You can also see **coherence scores by topic**:

# %%
print("Coherence score by topic (higher values are better): ", np.round(cm.get_coherence_per_topic(),4))
# Out:
# Coherence score by topic (higher values are better):  [-6.1508 -5.0146 -5.1128 -8.7517]
